# %% [markdown]
# # Exp 5 — MiniLM + W&B Sweep

# %%
# !pip install datasets wandb scikit-learn sentence-transformers gensim -q

# %%
import torch, torch.nn as nn, torch.optim as optim, torch.backends.cudnn as cudnn
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score
from datasets import load_dataset
import numpy as np, copy, wandb
SEED=42
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
cudnn.benchmark=False; cudnn.deterministic=True
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device:{device}')
# Out:
# Device:cuda

# %%
data=load_dataset('Sp1786/multiclass-sentiment-analysis-dataset')
def remove_empty(row):
    return all(row[f] not in [None,''] for f in ['id','text','label','sentiment'])
train_data=data['train'].filter(remove_empty)
dev_data=data['validation'].filter(remove_empty)
test_data=data['test'].filter(remove_empty)
output_size=len(set(train_data['label']))
train_labels=train_data['label']
test_labels_list=test_data['label']
print(f'Train:{len(train_data)}|Dev:{len(dev_data)}|Test:{len(test_data)}|Classes:{output_size}')
# Out:
# Train:31232|Dev:5205|Test:5205|Classes:3

# %%
from sentence_transformers import SentenceTransformer
model_emb=SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
train_np=model_emb.encode(train_data['text'],batch_size=128,show_progress_bar=True,convert_to_numpy=True)
dev_np=model_emb.encode(dev_data['text'],batch_size=128,show_progress_bar=True,convert_to_numpy=True)
test_np=model_emb.encode(test_data['text'],batch_size=128,show_progress_bar=True,convert_to_numpy=True)
input_size=384
train_t=torch.FloatTensor(train_np).to(device)
dev_t=torch.FloatTensor(dev_np).to(device)
test_t=torch.FloatTensor(test_np).to(device)
dev_labels_t=torch.tensor(dev_data['label'],dtype=torch.long).to(device)
print(f'MiniLM:{train_t.shape}')
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches:   0%|          | 0/244 [00:00<?, ?it/s]
# Batches:   0%|          | 0/41 [00:00<?, ?it/s]
# Batches:   0%|          | 0/41 [00:00<?, ?it/s]
# MiniLM:torch.Size([31232, 384])

# %%
class MLP(nn.Module):
    def __init__(self, i, h, o, d=0.0):
        super().__init__()
        self.fc1=nn.Linear(i,h)
        self.fc2=nn.Linear(h,h//2)
        self.fc3=nn.Linear(h//2,o)
        self.activation=nn.GELU()
        self.output_act=nn.Softmax(dim=1)
        self.dropout=nn.Dropout(p=d)
    def forward(self,x):
        x=self.dropout(self.activation(self.fc1(x)))
        x=self.dropout(self.activation(self.fc2(x)))
        return self.output_act(self.fc3(x))

# %%
def make_sweep_fn(train_t,dev_t,dev_l,test_t,inp,lbl):
    def train_fn():
        with wandb.init() as run:
            cfg=run.config
            torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
            model=MLP(inp,cfg.hidden_size,output_size,cfg.dropout).to(device)
            opt=optim.Adam(model.parameters(),lr=cfg.learning_rate,weight_decay=cfg.weight_decay)
            lfn=nn.CrossEntropyLoss()
            best_dev,best_state=0,None
            for epoch in range(cfg.num_epochs):
                model.train()
                eloss=0
                for i in range(0,len(train_t),cfg.batch_size):
                    bd=train_t[i:i+cfg.batch_size]
                    bl=torch.tensor(train_labels[i:i+cfg.batch_size],device=device)
                    out=model(bd)
                    loss=lfn(out,bl)
                    opt.zero_grad(); loss.backward(); opt.step()
                    eloss+=loss.item()
                model.eval()
                with torch.no_grad():
                    da=(torch.argmax(model(dev_t),dim=1)==dev_l).float().mean().item()
                if da>best_dev:
                    best_dev=da
                    best_state=copy.deepcopy(model.state_dict())
                wandb.log({'epoch':epoch+1,'dev_accuracy':da,'best_dev_accuracy':best_dev,'train_loss':eloss/len(train_t)})
            model.load_state_dict(best_state)
            model.eval()
            with torch.no_grad():
                tp=torch.argmax(model(test_t),dim=1)
                ta=accuracy_score(test_labels_list,tp.cpu().tolist())
            wandb.log({'test_accuracy':ta})
            print(f'[{lbl}] Dev:{best_dev:.4f}|Test:{ta*100:.2f}%')
    return train_fn

SWEEP_CFG={'method':'bayes','metric':{'name':'best_dev_accuracy','goal':'maximize'},
'parameters':{'learning_rate':{'distribution':'log_uniform_values','min':1e-5,'max':1e-3},
'hidden_size':{'values':[512,1000,2000]},'dropout':{'values':[0.0,0.1,0.2,0.3]},
'weight_decay':{'values':[0.0,1e-5,1e-4]},'num_epochs':{'values':[30,50]},
'batch_size':{'values':[128,256]}}}

# %%
wandb.login()
# Out:
# True

# %%
sweep_id=wandb.sweep({**SWEEP_CFG,'name':'exp5-minilm-v2'},project='nlp-hw1')
print(f'Sweep ID:{sweep_id}')
train_fn=make_sweep_fn(train_t,dev_t,dev_labels_t,test_t,input_size,'Exp5-MiniLM')
wandb.agent(sweep_id,function=train_fn,count=20)
# Out:
# Create sweep with ID: nc1gtm1u
# Sweep URL: https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u
# Sweep ID:nc1gtm1u
# wandb: Agent Starting Run: e2w19uqi with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0
# wandb: 	hidden_size: 1000
# wandb: 	learning_rate: 0.00023708029189232276
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 0
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071134-e2w19uqi</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/e2w19uqi' target="_blank">peach-sweep-1</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/e2w19uqi' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/e2w19uqi</a>
# [Exp5-MiniLM] Dev:0.6701|Test:65.74%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▅▇█████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▅▇█▇▆▆▆▆▆▅▄▄▄▆▃▃▃▄▄▄▄▃▃▄▃▃▃▃▄▄▄▅▄▄▆▅▅▅▅</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67012</td></tr><tr><td>dev_accuracy</td><td>0.66436</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.65744</td></tr><tr><td>train_loss</td><td>0.00651</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peach-sweep-1</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/e2w19uqi' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/e2w19uqi</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071134-e2w19uqi/logs</code>
# wandb: Agent Starting Run: j800kbnk with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 8.280508233179822e-05
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071216-j800kbnk</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/j800kbnk' target="_blank">pious-sweep-2</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/j800kbnk' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/j800kbnk</a>
# [Exp5-MiniLM] Dev:0.6694|Test:66.21%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▅▇█████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▅▇███████▇█████████▇▇▇▇▇▇▇▇▇█▇███▇███▇▇</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.66936</td></tr><tr><td>dev_accuracy</td><td>0.66667</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66206</td></tr><tr><td>train_loss</td><td>0.00661</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pious-sweep-2</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/j800kbnk' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/j800kbnk</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071216-j800kbnk/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: oapi1n2w with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 2.210589411456113e-05
# wandb: 	num_epochs: 30
# wandb: 	weight_decay: 0.0001
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071321-oapi1n2w</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/oapi1n2w' target="_blank">helpful-sweep-3</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/oapi1n2w' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/oapi1n2w</a>
# [Exp5-MiniLM] Dev:0.6694|Test:66.03%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▅▆▇▇▇████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▅▆▇▇▇████████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▅▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.66936</td></tr><tr><td>dev_accuracy</td><td>0.66936</td></tr><tr><td>epoch</td><td>30</td></tr><tr><td>test_accuracy</td><td>0.66033</td></tr><tr><td>train_loss</td><td>0.00672</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">helpful-sweep-3</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/oapi1n2w' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/oapi1n2w</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071321-oapi1n2w/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: s4iqjqyi with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.00020792618420736056
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071403-s4iqjqyi</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/s4iqjqyi' target="_blank">usual-sweep-4</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/s4iqjqyi' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/s4iqjqyi</a>
# [Exp5-MiniLM] Dev:0.6726|Test:66.13%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆██████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▄██▇▆▆▆▅▅▅▄▄▃▂▂▂▃▂▂▂▂▂▂▃▃▁▂▂▁▁▃▄▄▄▅▄▄▄▄▄</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67262</td></tr><tr><td>dev_accuracy</td><td>0.66667</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66129</td></tr><tr><td>train_loss</td><td>0.00327</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">usual-sweep-4</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/s4iqjqyi' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/s4iqjqyi</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071403-s4iqjqyi/logs</code>
# wandb: Agent Starting Run: a1drkjro with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.0002574056014229813
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071436-a1drkjro</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/a1drkjro' target="_blank">daily-sweep-5</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/a1drkjro' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/a1drkjro</a>
# [Exp5-MiniLM] Dev:0.6730|Test:66.07%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆██████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▇█▇█▇▇▇▇▇▅▅▅▄▄▄▄▄▅▄▄▄▃▂▁▂▃▃▃▃▅▅▇▆▆▇▇▇▇▇</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67301</td></tr><tr><td>dev_accuracy</td><td>0.66801</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66071</td></tr><tr><td>train_loss</td><td>0.00326</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">daily-sweep-5</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/a1drkjro' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/a1drkjro</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071436-a1drkjro/logs</code>
# wandb: Agent Starting Run: f3qof1ok with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.0008106291692051054
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 0.0001
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071508-f3qof1ok</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/f3qof1ok' target="_blank">helpful-sweep-6</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/f3qof1ok' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/f3qof1ok</a>
# [Exp5-MiniLM] Dev:0.6626|Test:65.73%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁███████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▇█▇▇▇▇▇▆▅▅▃▁▄▅▃▃▁▃▅▅▃▁▂▃▄▅▅▅▄▂▄▅▅▆▅▇▆▇▅▆</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.66263</td></tr><tr><td>dev_accuracy</td><td>0.65821</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.65725</td></tr><tr><td>train_loss</td><td>0.00331</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">helpful-sweep-6</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/f3qof1ok' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/f3qof1ok</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071508-f3qof1ok/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: fn5i8m5q with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 5.726811658921511e-05
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071549-fn5i8m5q</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/fn5i8m5q' target="_blank">spring-sweep-7</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/fn5i8m5q' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/fn5i8m5q</a>
# [Exp5-MiniLM] Dev:0.6711|Test:66.11%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆▇▇████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆▇▇████████████████████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67109</td></tr><tr><td>dev_accuracy</td><td>0.66609</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.6611</td></tr><tr><td>train_loss</td><td>0.00331</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">spring-sweep-7</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/fn5i8m5q' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/fn5i8m5q</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071549-fn5i8m5q/logs</code>
# wandb: Agent Starting Run: mbvh07yw with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.00013856275066546068
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071623-mbvh07yw</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/mbvh07yw' target="_blank">expert-sweep-8</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/mbvh07yw' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/mbvh07yw</a>
# [Exp5-MiniLM] Dev:0.6719|Test:66.47%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆██████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆██▇▇▅▅▅▅▆▅▅▅▅▄▄▅▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▃▃▄</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67185</td></tr><tr><td>dev_accuracy</td><td>0.66571</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66475</td></tr><tr><td>train_loss</td><td>0.0033</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">expert-sweep-8</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/mbvh07yw' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/mbvh07yw</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071623-mbvh07yw/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: gx8fmw5q with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.00038134803399509346
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071704-gx8fmw5q</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/gx8fmw5q' target="_blank">cool-sweep-9</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/gx8fmw5q' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/gx8fmw5q</a>
# [Exp5-MiniLM] Dev:0.6697|Test:65.63%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆██████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▃▆█▇▅▅▅▄▅▃▂▃▃▄▅▆▆▅▅▇▇██▆▆▄▃▂▁▁▃▃▄▇▆▅▆▆▄▄</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▄▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.66974</td></tr><tr><td>dev_accuracy</td><td>0.66282</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.65629</td></tr><tr><td>train_loss</td><td>0.00323</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cool-sweep-9</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/gx8fmw5q' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/gx8fmw5q</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071704-gx8fmw5q/logs</code>
# wandb: Agent Starting Run: s79u8zl0 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.00019205824010874305
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071737-s79u8zl0</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/s79u8zl0' target="_blank">glorious-sweep-10</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/s79u8zl0' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/s79u8zl0</a>
# [Exp5-MiniLM] Dev:0.6719|Test:66.32%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆██████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆███▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▆▅▅▅▅▆▆▆▆▆▅▅▆▆▆▆▆▅▆▆</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67185</td></tr><tr><td>dev_accuracy</td><td>0.66494</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66321</td></tr><tr><td>train_loss</td><td>0.00328</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glorious-sweep-10</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/s79u8zl0' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/s79u8zl0</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071737-s79u8zl0/logs</code>
# wandb: Agent Starting Run: atovpk0p with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.000537620090263102
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071809-atovpk0p</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/atovpk0p' target="_blank">glowing-sweep-11</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/atovpk0p' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/atovpk0p</a>
# [Exp5-MiniLM] Dev:0.6665|Test:65.49%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆██████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆█▅▆▇▅▁▄▅▄▅▄▃▄▄▆▆▅▇▃▂▂▄▆▅▃▁▃▂▅▃▄▇▆▆▄▄▄▂</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.66647</td></tr><tr><td>dev_accuracy</td><td>0.65841</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.65495</td></tr><tr><td>train_loss</td><td>0.00322</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glowing-sweep-11</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/atovpk0p' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/atovpk0p</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071809-atovpk0p/logs</code>
# wandb: Agent Starting Run: medfdfpv with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.2
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 7.590164900500351e-05
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 0.0001
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071841-medfdfpv</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/medfdfpv' target="_blank">divine-sweep-12</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/medfdfpv' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/medfdfpv</a>
# [Exp5-MiniLM] Dev:0.6699|Test:66.05%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆██████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆▇█████████████████████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.66993</td></tr><tr><td>dev_accuracy</td><td>0.6684</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66052</td></tr><tr><td>train_loss</td><td>0.00334</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">divine-sweep-12</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/medfdfpv' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/medfdfpv</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071841-medfdfpv/logs</code>
# wandb: Agent Starting Run: 2doey0qd with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.00014951014477022348
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 0.0001
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071914-2doey0qd</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/2doey0qd' target="_blank">rural-sweep-13</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/2doey0qd' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/2doey0qd</a>
# [Exp5-MiniLM] Dev:0.6707|Test:65.84%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆▇▇▇▇██████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆▇▇▇▇██▇▇█▇█████████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.6707</td></tr><tr><td>dev_accuracy</td><td>0.66455</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.65841</td></tr><tr><td>train_loss</td><td>0.00333</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rural-sweep-13</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/2doey0qd' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/2doey0qd</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071914-2doey0qd/logs</code>
# wandb: Agent Starting Run: ppcler6m with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 4.2520600499439866e-05
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 0.0001
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_071947-ppcler6m</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/ppcler6m' target="_blank">copper-sweep-14</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/ppcler6m' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/ppcler6m</a>
# [Exp5-MiniLM] Dev:0.6703|Test:66.42%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▅▇▇▇███████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▅▇▇████████████████████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▅▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67032</td></tr><tr><td>dev_accuracy</td><td>0.66782</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66417</td></tr><tr><td>train_loss</td><td>0.00334</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">copper-sweep-14</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/ppcler6m' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/ppcler6m</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_071947-ppcler6m/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: fi9lqvby with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.00016083363282208524
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 0.0001
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_072028-fi9lqvby</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/fi9lqvby' target="_blank">noble-sweep-15</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/fi9lqvby' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/fi9lqvby</a>
# [Exp5-MiniLM] Dev:0.6705|Test:65.73%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆▇▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆▇▇▇▇▇▇▇▇███▇███████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67051</td></tr><tr><td>dev_accuracy</td><td>0.66455</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.65725</td></tr><tr><td>train_loss</td><td>0.00333</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">noble-sweep-15</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/fi9lqvby' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/fi9lqvby</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_072028-fi9lqvby/logs</code>
# wandb: Agent Starting Run: n3hj7gwm with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.00021678802570418608
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 0.0001
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_072102-n3hj7gwm</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/n3hj7gwm' target="_blank">vague-sweep-16</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/n3hj7gwm' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/n3hj7gwm</a>
# [Exp5-MiniLM] Dev:0.6711|Test:65.82%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▅▆▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▅▆▇▇▆▆▇▇▇████▇▇▇▇▇▇▆▆▆▆▇▆▆▇▆▇▆▆▆▆▇▇▇▆▆▆</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67109</td></tr><tr><td>dev_accuracy</td><td>0.66455</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.65821</td></tr><tr><td>train_loss</td><td>0.00333</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vague-sweep-16</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/n3hj7gwm' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/n3hj7gwm</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_072102-n3hj7gwm/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: yjjs61h5 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 0.00011106083691919112
# wandb: 	num_epochs: 30
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_072144-yjjs61h5</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/yjjs61h5' target="_blank">denim-sweep-17</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/yjjs61h5' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/yjjs61h5</a>
# [Exp5-MiniLM] Dev:0.6720|Test:66.53%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆▇███████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆▇███████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67205</td></tr><tr><td>dev_accuracy</td><td>0.66647</td></tr><tr><td>epoch</td><td>30</td></tr><tr><td>test_accuracy</td><td>0.66532</td></tr><tr><td>train_loss</td><td>0.00332</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">denim-sweep-17</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/yjjs61h5' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/yjjs61h5</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_072144-yjjs61h5/logs</code>
# wandb: Agent Starting Run: xhcfd6x3 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	hidden_size: 1000
# wandb: 	learning_rate: 1.645244354200502e-05
# wandb: 	num_epochs: 30
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_072207-xhcfd6x3</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/xhcfd6x3' target="_blank">golden-sweep-18</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/xhcfd6x3' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/xhcfd6x3</a>
# [Exp5-MiniLM] Dev:0.6649|Test:65.92%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▃▃▃▄▅▆▇▇▇▇▇▇▇▇▇▇█████████████</td></tr><tr><td>dev_accuracy</td><td>▁▃▃▃▄▅▆▇▇▇▇▇▇▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>██▇▇▆▅▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.66494</td></tr><tr><td>dev_accuracy</td><td>0.66494</td></tr><tr><td>epoch</td><td>30</td></tr><tr><td>test_accuracy</td><td>0.65917</td></tr><tr><td>train_loss</td><td>0.00341</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">golden-sweep-18</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/xhcfd6x3' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/xhcfd6x3</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_072207-xhcfd6x3/logs</code>
# wandb: Agent Starting Run: 4935hjq3 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 6.166092965743005e-05
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_072228-4935hjq3</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/4935hjq3' target="_blank">frosty-sweep-19</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/4935hjq3' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/4935hjq3</a>
# [Exp5-MiniLM] Dev:0.6707|Test:66.32%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆▇█████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆▇█████████████████████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.6707</td></tr><tr><td>dev_accuracy</td><td>0.66628</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66321</td></tr><tr><td>train_loss</td><td>0.00331</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">frosty-sweep-19</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/4935hjq3' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/4935hjq3</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_072228-4935hjq3/logs</code>
# wandb: Agent Starting Run: icbqfbul with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	hidden_size: 2000
# wandb: 	learning_rate: 6.251435480584478e-05
# wandb: 	num_epochs: 50
# wandb: 	weight_decay: 1e-05
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260503_072301-icbqfbul</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/icbqfbul' target="_blank">icy-sweep-20</a></strong> to <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View project at <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a>
#  View sweep at <a href='https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/sweeps/nc1gtm1u</a>
#  View run at <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/icbqfbul' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/icbqfbul</a>
# [Exp5-MiniLM] Dev:0.6705|Test:66.38%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>▁▆▇█████████████████████████████████████</td></tr><tr><td>dev_accuracy</td><td>▁▆▇█████████████████████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_dev_accuracy</td><td>0.67051</td></tr><tr><td>dev_accuracy</td><td>0.6659</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>0.66378</td></tr><tr><td>train_loss</td><td>0.00331</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">icy-sweep-20</strong> at: <a href='https://wandb.ai/imeanseo_/nlp-hw1/runs/icbqfbul' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1/runs/icbqfbul</a><br> View project at: <a href='https://wandb.ai/imeanseo_/nlp-hw1' target="_blank">https://wandb.ai/imeanseo_/nlp-hw1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260503_072301-icbqfbul/logs</code>

# %%
USERNAME='imeanseo_'
api=wandb.Api()
sw=api.sweep(f'{USERNAME}/nlp-hw1/{sweep_id}')
best=sw.best_run()
print('\n'+'='*60)
print('🏆 Best Run Config:')
for k,v in dict(best.config).items():
    print(f'  {k:<20}: {v}')
print(f"\nBest Dev:{best.summary['best_dev_accuracy']:.4f}")
print(f"Test:{best.summary['test_accuracy']*100:.2f}%")
print('='*60)
# Out:
# wandb: Sorting runs by -summary_metrics.best_dev_accuracy
# ============================================================
# 🏆 Best Run Config:
#   dropout             : 0
#   batch_size          : 256
#   num_epochs          : 50
#   hidden_size         : 2000
#   weight_decay        : 1e-05
#   learning_rate       : 0.0002574056014229813
#
# Best Dev:0.6730
# Test:66.07%
# ============================================================

# %% [markdown]
# ## Best Config로 재학습 + 저장

# %%
# ⚠️ 위 출력 값으로 수정 (Transformer용 낮은 학습률)
BEST_H,BEST_LR,BEST_D,BEST_WD,BEST_EP,BEST_BS=256,0.0048,0.5,1e-5,50,256
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
final=MLP(input_size,BEST_H,output_size,BEST_D).to(device)
opt=optim.Adam(final.parameters(),lr=BEST_LR,weight_decay=BEST_WD)
lfn=nn.CrossEntropyLoss()
best_dev,best_state=0,None
for epoch in range(BEST_EP):
    final.train()
    for i in range(0,len(train_t),BEST_BS):
        bd=train_t[i:i+BEST_BS]
        bl=torch.tensor(train_labels[i:i+BEST_BS],device=device)
        loss=lfn(final(bd),bl)
        opt.zero_grad(); loss.backward(); opt.step()
    final.eval()
    with torch.no_grad():
        da=(torch.argmax(final(dev_t),dim=1)==dev_labels_t).float().mean().item()
    if da>best_dev:
        best_dev,best_state=da,copy.deepcopy(final.state_dict())
    print(f'Epoch {epoch+1}/{BEST_EP}|Dev:{da:.4f}')
final.load_state_dict(best_state)
torch.save(best_state,'best_model_exp5.pt')
with torch.no_grad():
    test_acc=accuracy_score(test_labels_list,torch.argmax(final(test_t),dim=1).cpu().tolist())
print(f'\n✅ 저장:best_model_exp5.pt|Dev:{best_dev:.4f}|Test:{test_acc*100:.2f}%')
# Out:
# Epoch 1/50|Dev:0.6476
# Epoch 2/50|Dev:0.6621
# Epoch 3/50|Dev:0.6592
# Epoch 4/50|Dev:0.6680
# Epoch 5/50|Dev:0.6663
# Epoch 6/50|Dev:0.6672
# Epoch 7/50|Dev:0.6701
# Epoch 8/50|Dev:0.6699
# Epoch 9/50|Dev:0.6719
# Epoch 10/50|Dev:0.6780
# Epoch 11/50|Dev:0.6732
# Epoch 12/50|Dev:0.6722
# Epoch 13/50|Dev:0.6719
# Epoch 14/50|Dev:0.6778
# Epoch 15/50|Dev:0.6803
# Epoch 16/50|Dev:0.6817
# Epoch 17/50|Dev:0.6778
# Epoch 18/50|Dev:0.6724
# Epoch 19/50|Dev:0.6765
# Epoch 20/50|Dev:0.6757
# Epoch 21/50|Dev:0.6684
# Epoch 22/50|Dev:0.6824
# Epoch 23/50|Dev:0.6770
# Epoch 24/50|Dev:0.6757
# Epoch 25/50|Dev:0.6765
# Epoch 26/50|Dev:0.6772
# Epoch 27/50|Dev:0.6778
# Epoch 28/50|Dev:0.6768
# Epoch 29/50|Dev:0.6774
# Epoch 30/50|Dev:0.6784
# Epoch 31/50|Dev:0.6792
# Epoch 32/50|Dev:0.6790
# Epoch 33/50|Dev:0.6753
# Epoch 34/50|Dev:0.6736
# Epoch 35/50|Dev:0.6793
# Epoch 36/50|Dev:0.6705
# Epoch 37/50|Dev:0.6742
# Epoch 38/50|Dev:0.6755
# Epoch 39/50|Dev:0.6744
# Epoch 40/50|Dev:0.6768
# Epoch 41/50|Dev:0.6751
# Epoch 42/50|Dev:0.6778
# Epoch 43/50|Dev:0.6755
# Epoch 44/50|Dev:0.6774
# Epoch 45/50|Dev:0.6790
# Epoch 46/50|Dev:0.6799
# Epoch 47/50|Dev:0.6820
# Epoch 48/50|Dev:0.6782
# Epoch 49/50|Dev:0.6784
# Epoch 50/50|Dev:0.6795
#
# ✅ 저장:best_model_exp5.pt|Dev:0.6824|Test:67.15%
